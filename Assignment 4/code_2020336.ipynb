# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### EDA & PREPROCESSING

# %%
df = pd.read_csv('Country-data.csv')

# %%
df
# Out:
#                  country  child_mort  exports  health  imports  income  \
# 0            Afghanistan        90.2     10.0    7.58     44.9    1610
# 1                Albania        16.6     28.0    6.55     48.6    9930
# 2                Algeria        27.3     38.4    4.17     31.4   12900
# 3                 Angola       119.0     62.3    2.85     42.9    5900
# 4    Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# ..                   ...         ...      ...     ...      ...     ...
# 162              Vanuatu        29.2     46.6    5.25     52.7    2950
# 163            Venezuela        17.1     28.5    4.91     17.6   16500
# 164              Vietnam        23.3     72.0    6.84     80.2    4490
# 165                Yemen        56.3     30.0    5.18     34.4    4480
# 166               Zambia        83.1     37.0    5.89     30.9    3280
#
#      inflation  life_expec  total_fer   gdpp
# 0         9.44        56.2       5.82    553
# ...

# %%
df.head()
# Out:
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
#
#    inflation  life_expec  total_fer   gdpp
# 0       9.44        56.2       5.82    553
# 1       4.49        76.3       1.65   4090
# 2      16.10        76.5       2.89   4460
# 3      22.40        60.1       6.16   3530
# 4       1.44        76.8       2.13  12200

# %%
df.shape
# Out:
# (167, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     167 non-null    object
#  1   child_mort  167 non-null    float64
#  2   exports     167 non-null    float64
#  3   health      167 non-null    float64
#  4   imports     167 non-null    float64
#  5   income      167 non-null    int64
#  6   inflation   167 non-null    float64
#  7   life_expec  167 non-null    float64
#  8   total_fer   167 non-null    float64
#  9   gdpp        167 non-null    int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 13.2+ KB

# %%
df.describe()
# Out:
#        child_mort     exports      health     imports         income  \
# count  167.000000  167.000000  167.000000  167.000000     167.000000
# mean    38.270060   41.108976    6.815689   46.890215   17144.688623
# std     40.328931   27.412010    2.746837   24.209589   19278.067698
# min      2.600000    0.109000    1.810000    0.065900     609.000000
# 25%      8.250000   23.800000    4.920000   30.200000    3355.000000
# 50%     19.300000   35.000000    6.320000   43.300000    9960.000000
# 75%     62.100000   51.350000    8.600000   58.750000   22800.000000
# max    208.000000  200.000000   17.900000  174.000000  125000.000000
#
#         inflation  life_expec   total_fer           gdpp
# count  167.000000  167.000000  167.000000     167.000000
# mean     7.781832   70.555689    2.947964   12964.155689
# std     10.570704    8.893172    1.513848   18328.704809
# min     -4.210000   32.100000    1.150000     231.000000
# 25%      1.810000   65.300000    1.795000    1330.000000
# ...

# %%
#check for null values
df.isnull().sum()
# Out:
# country       0
# child_mort    0
# exports       0
# health        0
# imports       0
# income        0
# inflation     0
# life_expec    0
# total_fer     0
# gdpp          0
# dtype: int64

# %%
df1 = df.copy()
df1.drop(['country'], axis=1, inplace=True)
corr = df1.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.pairplot(df)

# %%
#Box plot for outliers  for all columns
for i in df.columns:
    if i == 'country':
        continue
    sns.boxplot(df[i],orient="h",color="g")
    plt.show()

# %%
for i in df.columns:
    if i == 'country':
        continue
    sns.distplot(df[i])
    plt.show()
# Out:
# C:\Users\SHOURYA\AppData\Local\Temp\ipykernel_23108\2769817721.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# C:\Users\SHOURYA\AppData\Local\Temp\ipykernel_23108\2769817721.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df1)
df_scaled = pd.DataFrame(df_scaled, columns=df1.columns)
df_scaled.head()
# Out:
#    child_mort   exports    health   imports    income  inflation  life_expec  \
# 0    1.291532 -1.138280  0.279088 -0.082455 -0.808245   0.157336   -1.619092
# 1   -0.538949 -0.479658 -0.097016  0.070837 -0.375369  -0.312347    0.647866
# 2   -0.272833 -0.099122 -0.966073 -0.641762 -0.220844   0.789274    0.670423
# 3    2.007808  0.775381 -1.448071 -0.165315 -0.585043   1.387054   -1.179234
# 4   -0.695634  0.160668 -0.286894  0.497568  0.101732  -0.601749    0.704258
#
#    total_fer      gdpp
# 0   1.902882 -0.679180
# 1  -0.859973 -0.485623
# 2  -0.038404 -0.465376
# 3   2.128151 -0.516268
# 4  -0.541946 -0.041817

# %% [markdown]
# ### Part B: PCA

# %%
from sklearn.decomposition import PCA
pca = PCA()
pca1 = pca.fit_transform(df_scaled)
cols = []
for i in range(1, 10):
    cols.append('PC'+str(i))
pca1 = pd.DataFrame(pca1, columns=cols)
pca1
# Out:
#           PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0   -2.913025  0.095621 -0.718118  1.005255 -0.158310 -0.254597  0.383000
# 1    0.429911 -0.588156 -0.333486 -1.161059  0.174677  0.084579  0.248919
# 2   -0.285225 -0.455174  1.221505 -0.868115  0.156475 -0.401696 -0.087214
# 3   -2.932423  1.695555  1.525044  0.839625 -0.273209 -0.547996 -0.440835
# 4    1.033576  0.136659 -0.225721 -0.847063 -0.193007 -0.206919  0.241978
# ..        ...       ...       ...       ...       ...       ...       ...
# 162 -0.820631  0.639570 -0.389923 -0.706595 -0.395748  0.009059 -0.098738
# 163 -0.551036 -1.233886  3.101350 -0.115311  2.082581  0.097274  0.206735
# 164  0.498524  1.390744 -0.238526 -1.074098  1.176081  0.051607 -0.143627
# 165 -1.887451 -0.109453  1.109752  0.056257  0.618365 -0.540917  0.060256
# 166 -2.864064  0.485998  0.223167  0.816364 -0.274068  0.201378 -0.442185
#
#           PC8       PC9
# 0    0.415076 -0.014148
# 1   -0.221042  0.173316
# ...

# %%
print(pca.explained_variance_ratio_)
sum = 0
for i in range(0,len(pca.explained_variance_ratio_)):
    sum = sum + pca.explained_variance_ratio_[i]
    print(sum)
# Out:
# [0.4595174  0.17181626 0.13004259 0.11053162 0.07340211 0.02484235
#  0.0126043  0.00981282 0.00743056]
# 0.45951739786095924
# 0.6313336543771412
# 0.7613762433466718
# 0.871907861402391
# 0.9453099756439514
# 0.9701523224082288
# 0.982756626389879
# 0.9925694437691406
# 1.0

# %%
plt.bar(cols, pca.explained_variance_ratio_)
plt.xlabel('PCA Components')
plt.ylabel('Variance Ratio')
plt.title('PCA Variance Ratio')
plt.show()

# %%
#Choosing the number of components = 4
pca_final = pca1[['PC1', 'PC2', 'PC3', 'PC4']]

# %%
sns.heatmap(pca_final.corr(), annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot: >

# %%
#scatter plot for all columns of pca_final
for i in pca_final.columns:
    for j in pca_final.columns:
        if i == j:
            continue
        sns.scatterplot(data = pca_final,x = pca_final[i], y = pca_final[j])
        plt.show()

# %%
#Heat map for correlation between original data and pca_final
pca_final_corr = pd.DataFrame()
pca_final_corr['PC1'] = df_scaled.corrwith(pca_final['PC1'])
pca_final_corr['PC2'] = df_scaled.corrwith(pca_final['PC2'])
pca_final_corr['PC3'] = df_scaled.corrwith(pca_final['PC3'])
pca_final_corr['PC4'] = df_scaled.corrwith(pca_final['PC4'])
pca_final_corr.head()
sns.heatmap(pca_final_corr, annot=True, cmap='coolwarm')
plt.show()

# %%
#Final Data to be used for k-means clustering
pca = PCA(n_components=4)
df_final = pca.fit_transform(df_scaled)
df_final = pd.DataFrame(df_final, columns=['PC_1', 'PC_2', 'PC_3', 'PC_4'])
df_final.head()
# Out:
#        PC_1      PC_2      PC_3      PC_4
# 0 -2.913025  0.095621 -0.718118  1.005255
# 1  0.429911 -0.588156 -0.333486 -1.161059
# 2 -0.285225 -0.455174  1.221505 -0.868115
# 3 -2.932423  1.695555  1.525044  0.839625
# 4  1.033576  0.136659 -0.225721 -0.847063

# %% [markdown]
# ### KMEANS CLUSTERING

# %%
df_final
# Out:
#          PC_1      PC_2      PC_3      PC_4
# 0   -2.913025  0.095621 -0.718118  1.005255
# 1    0.429911 -0.588156 -0.333486 -1.161059
# 2   -0.285225 -0.455174  1.221505 -0.868115
# 3   -2.932423  1.695555  1.525044  0.839625
# 4    1.033576  0.136659 -0.225721 -0.847063
# ..        ...       ...       ...       ...
# 162 -0.820631  0.639570 -0.389923 -0.706595
# 163 -0.551036 -1.233886  3.101350 -0.115311
# 164  0.498524  1.390744 -0.238526 -1.074098
# 165 -1.887451 -0.109453  1.109752  0.056257
# 166 -2.864064  0.485998  0.223167  0.816364
#
# [167 rows x 4 columns]

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
#Elbow method
sse = []
for i in range(2, 11):
    kmeans = KMeans(n_clusters=i, random_state=0)
    kmeans.fit(df_final)
    sse.append(kmeans.inertia_)
plt.plot(range(2, 11), sse)
plt.xlabel('Number of Clusters')
plt.ylabel('SSE')
plt.title('Elbow Method')
plt.show()
# Out:
# C:\Users\SHOURYA\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\SHOURYA\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
#Silhouette Score
sil = []
for i in range(2, 11):
    kmeans = KMeans(n_clusters=i, random_state=0)
    kmeans.fit(df_final)
    sil.append(silhouette_score(df_final, kmeans.labels_))
plt.plot(range(2, 11), sil)
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Score')
plt.show()
# Out:
# C:\Users\SHOURYA\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\SHOURYA\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
#K = 
kmeans = KMeans(n_clusters=4)
kmeans.fit(df_final)
df_final['Cluster Assigned'] = kmeans.labels_
df_final
# Out:
# C:\Users\SHOURYA\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
#          PC_1      PC_2      PC_3      PC_4  Cluster Assigned
# 0   -2.913025  0.095621 -0.718118  1.005255                 1
# 1    0.429911 -0.588156 -0.333486 -1.161059                 0
# 2   -0.285225 -0.455174  1.221505 -0.868115                 0
# 3   -2.932423  1.695555  1.525044  0.839625                 1
# 4    1.033576  0.136659 -0.225721 -0.847063                 0
# ..        ...       ...       ...       ...               ...
# 162 -0.820631  0.639570 -0.389923 -0.706595                 0
# 163 -0.551036 -1.233886  3.101350 -0.115311                 0
# ...

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   PC_1              167 non-null    float64
#  1   PC_2              167 non-null    float64
#  2   PC_3              167 non-null    float64
#  3   PC_4              167 non-null    float64
#  4   Cluster Assigned  167 non-null    int32
# dtypes: float64(4), int32(1)
# memory usage: 6.0 KB

# %%
ax = df_final['Cluster Assigned'].value_counts().plot(kind='bar')
plt.xlabel('Cluster Assigned')
plt.ylabel('Count')

for p in ax.patches:
    height = p.get_height()
    ax.text(x = p.get_x()+(p.get_width()/2),y = height//2, s = height, ha = 'center')

plt.show()

# %%
df_final['Country'] = df['country']
df['Cluster Assigned'] = df_final['Cluster Assigned']
df_scaled['Cluster Assigned'] = df_final['Cluster Assigned']
df_scaled['Country'] = df['country']

# %%
df
# Out:
#                  country  child_mort  exports  health  imports  income  \
# 0            Afghanistan        90.2     10.0    7.58     44.9    1610
# 1                Albania        16.6     28.0    6.55     48.6    9930
# 2                Algeria        27.3     38.4    4.17     31.4   12900
# 3                 Angola       119.0     62.3    2.85     42.9    5900
# 4    Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# ..                   ...         ...      ...     ...      ...     ...
# 162              Vanuatu        29.2     46.6    5.25     52.7    2950
# 163            Venezuela        17.1     28.5    4.91     17.6   16500
# 164              Vietnam        23.3     72.0    6.84     80.2    4490
# 165                Yemen        56.3     30.0    5.18     34.4    4480
# 166               Zambia        83.1     37.0    5.89     30.9    3280
#
#      inflation  life_expec  total_fer   gdpp  Cluster Assigned
# ...

# %%
df_final
# Out:
#          PC_1      PC_2      PC_3      PC_4  Cluster Assigned  \
# 0   -2.913025  0.095621 -0.718118  1.005255                 1
# 1    0.429911 -0.588156 -0.333486 -1.161059                 0
# 2   -0.285225 -0.455174  1.221505 -0.868115                 0
# 3   -2.932423  1.695555  1.525044  0.839625                 1
# 4    1.033576  0.136659 -0.225721 -0.847063                 0
# ..        ...       ...       ...       ...               ...
# 162 -0.820631  0.639570 -0.389923 -0.706595                 0
# 163 -0.551036 -1.233886  3.101350 -0.115311                 0
# 164  0.498524  1.390744 -0.238526 -1.074098                 0
# 165 -1.887451 -0.109453  1.109752  0.056257                 1
# 166 -2.864064  0.485998  0.223167  0.816364                 1
#
#                  Country
# 0            Afghanistan
# 1                Albania
# 2                Algeria
# 3                 Angola
# 4    Antigua and Barbuda
# ..                   ...
# 162              Vanuatu
# ...

# %%
# Plot the clusters on a 2D scatter plot. 
l = [['PC_1', 'PC_2'], ['PC_1', 'PC_3'], ['PC_1', 'PC_4'],['PC_2', 'PC_3'], ['PC_2', 'PC_4'],['PC_3', 'PC_4']]
for i in l:
    sns.scatterplot(data=df_final, x=i[0], y=i[1], hue='Cluster Assigned', palette='Set1')
    plt.show()

# %%
#Cluster 0
df[df['Cluster Assigned'] == 0].describe()
# Out:
#        child_mort    exports     health     imports        income  inflation  \
# count   87.000000  87.000000  87.000000   87.000000     87.000000  87.000000
# mean    21.113793  41.291828   6.217241   47.636390  13297.586207   7.371506
# std     13.925092  19.523609   2.145495   19.759309   8980.625783   7.821240
# min      3.400000   0.109000   1.970000    0.065900   1990.000000  -4.210000
# 25%     10.700000  26.900000   4.885000   32.700000   6720.000000   2.320000
# 50%     17.400000  37.700000   5.980000   48.700000  10900.000000   5.710000
# 75%     26.900000  52.050000   7.395000   60.550000  17900.000000   9.905000
# max     64.400000  93.800000  14.200000  108.000000  45400.000000  45.900000
#
#        life_expec  total_fer          gdpp  Cluster Assigned
# count   87.000000  87.000000     87.000000              87.0
# mean    73.147126   2.251954   7158.298851               0.0
# std      3.829653   0.672577   5656.749026               0.0
# ...

# %%
#Cluster 1
df[df['Cluster Assigned'] == 1].describe()
# Out:
#        child_mort    exports     health     imports        income   inflation  \
# count   48.000000  48.000000  48.000000   48.000000     48.000000   48.000000
# mean    91.610417  29.571042   6.433542   43.133333   3897.354167   11.911146
# std     34.319855  18.200215   2.651959   18.418658   5590.168621   15.362485
# min     28.100000   2.200000   2.200000   17.200000    609.000000    0.885000
# 25%     63.675000  17.025000   4.525000   29.900000   1390.000000    4.080000
# 50%     89.750000  24.350000   5.675000   41.500000   1860.000000    8.855000
# 75%    111.000000  39.400000   8.327500   50.025000   3522.500000   16.600000
# max    208.000000  85.800000  13.100000  101.000000  33700.000000  104.000000
#
#        life_expec  total_fer          gdpp  Cluster Assigned
# count   48.000000  48.000000     48.000000              48.0
# mean    59.239583   4.992083   1909.208333               1.0
# std      6.384914   1.036192   2925.911009               0.0
# ...

# %%
#Cluster 2
df[df['Cluster Assigned'] == 2].describe()
# Out:
#        child_mort     exports     health    imports         income  inflation  \
# count   29.000000   29.000000  29.000000  29.000000      29.000000  29.000000
# mean     4.982759   45.703448   9.245862  39.513793   45762.068966   2.727793
# std      2.191227   22.110332   3.296145  17.720604   19932.178108   4.341140
# min      2.600000   12.400000   1.810000  13.600000   27200.000000  -3.220000
# 25%      3.800000   28.200000   8.950000  28.000000   35800.000000   0.643000
# 50%      4.200000   42.300000   9.540000  32.900000   40700.000000   1.160000
# 75%      5.200000   64.000000  11.000000  47.800000   45700.000000   3.220000
# max     10.800000  103.000000  17.900000  86.500000  125000.000000  16.700000
#
#        life_expec  total_fer          gdpp  Cluster Assigned
# count   29.000000  29.000000     29.000000              29.0
# mean    80.386207   1.814828  44065.517241               2.0
# std      1.464758   0.359778  14752.173590               0.0
# ...

# %%
#Cluster 3
df[df['Cluster Assigned'] == 3].describe()
# Out:
#        child_mort     exports    health     imports        income  inflation  \
# count    3.000000    3.000000  3.000000    3.000000      3.000000   3.000000
# mean     4.133333  176.000000  6.793333  156.666667  64033.333333   2.468000
# std      2.309401   23.515952  2.492877   16.165808  32460.642836   2.179718
# min      2.800000  153.000000  3.960000  142.000000  28300.000000  -0.046000
# 25%      2.800000  164.000000  5.865000  148.000000  50200.000000   1.787000
# 50%      2.800000  175.000000  7.770000  154.000000  72100.000000   3.620000
# 75%      4.800000  187.500000  8.210000  164.000000  81900.000000   3.725000
# max      6.800000  200.000000  8.650000  174.000000  91700.000000   3.830000
#
#        life_expec  total_fer           gdpp  Cluster Assigned
# count    3.000000   3.000000       3.000000               3.0
# mean    81.433333   1.380000   57566.666667               3.0
# std      1.205543   0.240624   43011.665084               0.0
# ...

# %%
df[df['country'] == 'India']
# Out:
#    country  child_mort  exports  health  imports  income  inflation  \
# 69   India        58.8     22.6    4.05     27.1    4410       8.98
#
#     life_expec  total_fer  gdpp  Cluster Assigned
# 69        66.2        2.6  1350                 0

# %%
dic = {3:'Very Developed',2:'Developed', 0:'Developing', 1:'Under-Developed'}
df['Final Category'] = df['Cluster Assigned'].map(dic)

# %%
df
# Out:
#                  country  child_mort  exports  health  imports  income  \
# 0            Afghanistan        90.2     10.0    7.58     44.9    1610
# 1                Albania        16.6     28.0    6.55     48.6    9930
# 2                Algeria        27.3     38.4    4.17     31.4   12900
# 3                 Angola       119.0     62.3    2.85     42.9    5900
# 4    Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# ..                   ...         ...      ...     ...      ...     ...
# 162              Vanuatu        29.2     46.6    5.25     52.7    2950
# 163            Venezuela        17.1     28.5    4.91     17.6   16500
# 164              Vietnam        23.3     72.0    6.84     80.2    4490
# 165                Yemen        56.3     30.0    5.18     34.4    4480
# 166               Zambia        83.1     37.0    5.89     30.9    3280
#
#      inflation  life_expec  total_fer   gdpp  Cluster Assigned  \
# ...
